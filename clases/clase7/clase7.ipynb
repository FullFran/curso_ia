# %% [markdown]
# ## Repaso decoradores:
#
# fun == elemento callable, se puede renombrar, se puede hacer composición de funciones...

# %%
from functools import wraps


def decorador(fun):
    # Con esto es más facil usar decoradores, por ejemplo el fun.__name__ sigue siendo el de la función en vez del del wrapper.
    @ wraps(fun)
    def wrapper(*args, **kwargs):
        print('decoro la función antes')
        result = fun(*args, **kwargs)
        print('decoro la fun después')
        return result
    return wrapper


@ decorador
def fun():
    print('Soy fun')


fun()
# Out:
# decoro la función antes
# Soy fun
# decoro la fun después

# %% [markdown]
# ## Repaso de excepciones:
#
# si te da error se para el programa... Pero queremos controlar el proceso de cuando salta un error.
#
#     try:
#         intenta esto
#     except Exception as e:
#         print(e) # así podemos ver que excepción ha saltado, te printea el error.
#         si no funciona haz esto
#     else:
#         si no ha habido excepciones haz esto
#     finally:
#         si o si haz esto al final.
#
# En except puedes poner el tipo de excepción que es y que hacer en ese caso, por ejemplo con Aricmetic Error
# poniendo como:
#
#     try:
#         intenta esto
#     except AricmeticError:
#         si no funciona  por un error aricmetico haz esto
#     execpt otro dipo de error:
#         si está este tipo de error haz esto, puedes poner los que quieras.
#     else:
#         si no ha habido excepciones haz esto
#     finally:
#         si o si haz esto al final.
#
# Puedes crearte tus propios errores personalizados, por ejemplo si un número es menor que 18.
#
#     class error_personalizado:
#      ............ (mirar como se construye)

# %% [markdown]
# ## Repaso de numpy (no he copiado el repaso)
#
# se puede hacer un array en numpy con distribución normal:
#
# arr_normal = np.random.normal(10,5,400)

# %%
import numpy as np
import random

# %%
def tirardados(n_dados):
    dados = np.round(np.random.random(n_dados)*6, 0)
    return int(np.sum(dados))


tirardados(6)
# Out:
# 14

# %% [markdown]
# # Matplotlib:

# %%
import matplotlib.pyplot as plt
# plt.style.use('seaborn-v0_8-white')
import numpy as np

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
x = np.linspace(-10, 10)
def y(x): return x**2
def z(x): return -x**2 + 100


plt.plot(x, y(x), marker='+', c='skyblue', label='Positiva', ls=' ')
plt.plot(x, z(x), c='salmon', linewidth='1', ls='--', label='Negativa')
plt.legend()

plt.grid(axis='x')
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('Parábolas')
plt.show()

# %%
# subplot: separa el plot en varias partes.

# plt.subplot(N_filas, N_columnas, primera posición)


plt.subplot(2, 1, 1)
plt.grid()
plt.title('arriba')
plt.scatter(x, y(x), c='skyblue')

plt.subplot(2, 1, 2)
plt.plot(x, z(x), c='salmon')

plt.show()

# %%
# graficos de barras:
x = ['peras', 'manzanas']
y = [2, 10]

plt.bar(x, y)
plt.show()

# %%
x = np.random.normal(50, 10, 5000)

plt.hist(x)
plt.show()

# %% [markdown]
# Una estación meteorológica da mediciones de 3 elementos: la temperatura, la humedad y la presión atmosférica
#
# La temperatura se mide en ºC y tiene un error de medición de 1 ºC
#
# La humedad se mide en porcentaje y tiene un error del 5 %
#
# La presión de mide en HPa tiene un error de 50HPa
#
# Si la estación toma 480 mediciones al día. Haga un script que:
#
# a) Genere tres arrays con las mediciones de cada uno de los datos. Estos array tendrán una distribución normal.
#
# b) Pudiendo usar los arrays anteriores, genere 3 arrays más realistas en los que:
#
# La humedad se ha mantenido en una media constante, centrada en el 80%
#
# La presión ha ido disminuyendo linealmente desde los 1000 HPa a los 800 Hpa
#
# La temperatura ha seguido una curva senoidal o cosenoidal, empezando alrededor de los 5 ºC, subiendo hasta los 20 ºC a mediodía y, finalmente, volviendo a los 5 ºC a medianoche.
#
# c) Con los datos anteriores, genere:
#
# 3 gráficos independientes para cada una
#
# 1 gráfico que contenga los 3 datos superpuestos
#
# Un plot con 3 gráficos en horizontal
#
# d) Se ha añadido además un pluviómetro para medir la lluvia caída durante una semana. Genere el registro de lluvia en mm de una semana y represente en un gráfico de barras la lluvia caída a lo largo de ella, de lunes a domingo.

# %%
# a) Genere tres arrays con las mediciones de cada uno de los datos. Estos array tendrán una distribución normal.

T = np.random.normal(25, 1, 480)
dT = 1
H = np.random.normal(80, 0.05 * 80, 480)
dh = 0.05 * H
p = np.random.normal(800, 1, 480)
dp = np.ones(len(p)) * 50

# %%
plt.style.use("seaborn-v0_8-pastel")

# %%
# b) Pudiendo usar los arrays anteriores, genere 3 arrays más realistas en los que:
x = np.linspace(0, 24, 480)

Hb = H
plt.scatter(x, Hb)
plt.title('Humedad')
plt.show()


def t(x): return 15 * np.sin(x / 24 * np.pi) + 5


x = np.linspace(0, 24, 480)

Tb = t(x) + np.random.normal(0, 1, 480)

print(np.max(Tb))
plt.scatter(x, Tb)
plt.title('Temperatura')
plt.show()


def pp(x): return (1000 - (1000-800)/24 * x) / 800


pb = p * pp(x)

plt.scatter(x, pb)
plt.title('Presion')
plt.show()
# Out:
# 22.477729758703756

# %%
plt.scatter(x, Hb, label='Humedad')
plt.scatter(x, Tb, label='Temperatura')
plt.scatter(x, pb, label='Presión')
plt.legend()
plt.title('Todos juntos')
plt.show()

# %%
plt.figure(figsize=(20, 16))
plt.subplot(3, 1, 1)
plt.ylabel('%')
plt.scatter(x, Hb, c='skyblue', label='Humedad')
plt.legend()
plt.subplot(3, 1, 2)
plt.ylabel('ºC')
plt.scatter(x, Tb, c='salmon', label='Temperatura')
plt.legend()
plt.subplot(3, 1, 3)
plt.scatter(x, pb, c='lightgreen', label='Presión')
plt.ylabel('Hp')
plt.legend()
plt.show()

# %% [markdown]
# d) Se ha añadido además un pluviómetro para medir la lluvia caída durante una semana. Genere el registro de lluvia en mm de una semana y represente en un gráfico de barras la lluvia caída a lo largo de ella, de lunes a domingo.

# %%
xp = ['Lunes', 'Martes', 'Miércoles',
      'Viernes', 'Jueves', 'Sábado', 'Domingo']
yp = np.random.normal(0, 100, 7)
for i, y in enumerate(yp):
    if y < 0:
        yp[i] = 0


plt.bar(xp, yp)
plt.title('Precipitaciones (mm) por día')
plt.ylabel('mm')
plt.show()

yacum = yp
for i, elem in enumerate(yacum[1:]):
    yacum[i+1] += yacum[i]

plt.bar(xp, yacum)
plt.title('Precipitaciones acumuladas (mm)')
plt.ylabel('mm')
plt.show()

# %% [markdown]
# # Tratamiento de imágenes y PDF
#
# Se trabaja mucho con estos archivos en la empresa.
#
# # os, sys y shutil.
#
# Vamos a aprender a comunicarnos con el sistema operativo, para ello usamos:
#
#     os: directorios
#     sys: permite usar el intérprete de python
#     shutil: parecido a os pero con funcionalidades añadidas (sobretodo eliminar carpetas, comprimir archivos...)
#
# se puede usar copiar path y añadir 'r' al inicio y así lo coge raw:
#
#     path = r'C:\Users\Francisco\Desktop\curso_ia\clases\clase1\ejercicios.html'
#
# ## Módulo os:

# %%
import os

# %%
# Vamos a ver como movernos, listar... con os

wd = os.getcwd() # Nos da el directorio de trabajo.
# En el notebook como los pilla vs code es el directorio donde está el notebook
print(wd)

print(os.listdir())

os.chdir('../')
wd2 = os.getcwd() # Nos da el directorio de trabajo.
# En el notebook como los pilla vs code es el directorio donde está el notebook
print(wd2)

os.chdir(wd)

wd = os.getcwd() # Nos da el directorio de trabajo.
# En el notebook como los pilla vs code es el directorio donde está el notebook
print(wd)
# Out:
# c:\Users\Francisco\Desktop\curso_ia\clases\clase7
# ['asd', 'clase7.ipynb', 'ejemplo.txt']
# c:\Users\Francisco\Desktop\curso_ia\clases
# c:\Users\Francisco\Desktop\curso_ia\clases\clase7

# %%
print(os.path.exists('clase7.ipynb'))  # Devuelve un booleano de si existe o no el archivo / directorio

print(os.path.isdir('clase7.ipynb')) # Devuelve un booleano de si existe el folder (directorio)

print(os.path.isfile('clase7.ipynb')) # Devuelve un booleano de si existe el archivo (file)
# Out:
# True
# False
# True

# %%
#if os.path.isdir('mkdir'):  # así se borraría un folder
#    os.remove('mkdir')  # me faltan permisos
#if not os.path.isdir('mkdir'):
#    os.mkdir('mkdir')

# %%
import shutil

# %%
# mejor usar shutil:

#shutil.rmtree('mkdir') # con este borro todo lo dentro del directorio y si tengo permiso
#shutil.copytree(source_path, dest_path)
#shutil.move()

# %%
#copiar algo a algun sitio con shutil
os.chdir(wd)
if os.path.isdir('asd'):
    shutil.rmtree('asd')

os.mkdir('asd')

shutil.copy('ejemplo.txt', 'asd/ejemplo_copy.txt') # asi copiamos

os.chdir(wd)

# tengo que hacer ejemplos de comprimir archivos.

# %%
from PIL import Image

# %%
img = Image.open('output.png')

# El origen de coordenadas está en la esquina superior izquierda (el positivo es hacia abajo)
# Importatnes: crop para cortar
# paste pega una sobre otra
# resize resize a ancho, alto
# rotate rota en hexadecimal
# save guarda la imagen (img.save(nombre del archivo, format=extension))
#img.filename
#ImageDraw para dibujar en la imagen.

# %% [markdown]
# ## trabajamos con pdf:
# con pypdf2 y pypdf3
# y fpdf
# pypdf2 es la más usada

# %%
import PyPDF2

# %%
pdf = open('EJERCICIOS2.pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(pdf)
for i in range(pdf_reader.numPages):
    page = pdfReader.getPage(i)
    print(page.extractText())
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[11], line 3
#       1 pdf = open('EJERCICIOS2.pdf', 'rb')
#       2 pdf_reader = PyPDF2.PdfReader(pdf)
# ----> 3 for i in range(pdf_reader.numPages):
#       4     page = pdfReader.getPage(i)
#       5     print(page.extractText())
#
# File c:\Users\Francisco\anaconda3\envs\cursoIA\lib\site-packages\PyPDF2\_reader.py:467, in PdfReader.numPages(self)
#     460 @property
#     461 def numPages(self) -> int:  # pragma: no cover
#     462     """
#     463     .. deprecated:: 1.28.0
#     464
#     465         Use :code:`len(reader.pages)` instead.
#     466     """
# --> 467     deprecation_with_replacement("reader.numPages", "len(reader.pages)", "3.0.0")
#     468     return self._get_num_pages()
#
# File c:\Users\Francisco\anaconda3\envs\cursoIA\lib\site-packages\PyPDF2\_utils.py:369, in deprecation_with_replacement(old_name, new_name, removed_in)
#     363 def deprecation_with_replacement(
#     364     old_name: str, new_name: str, removed_in: str = "3.0.0"
#     365 ) -> None:
#     366     """
#     367     Raise an exception that a feature was already removed, but has a replacement.
#     368     """
# --> 369     deprecation(DEPR_MSG_HAPPENED.format(old_name, removed_in, new_name))
#
# File c:\Users\Francisco\anaconda3\envs\cursoIA\lib\site-packages\PyPDF2\_utils.py:351, in deprecation(msg)
#     350 def deprecation(msg: str) -> None:
# --> 351     raise DeprecationError(msg)
#
# DeprecationError: reader.numPages is deprecated and was removed in PyPDF2 3.0.0. Use len(reader.pages) instead.

# %%
from fpdf import FPDF

# %% [markdown]
# Mirar como funca el bicho si llego a trabajar con estos bichos.

# %% [markdown]
# 20) Cree un .pdf que guarde un título (ej.: arial 36) y debajo una imagen que abarque
# buena parte de la página. Después:
#
# a) Añada una página en blanco
#
# b) Añada una página en la que se añadan, al menos, 3 líneas de texto normal
#
# c) guarde el pdf
