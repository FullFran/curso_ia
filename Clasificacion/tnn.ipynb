# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import make_circles

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

mish=nn.Mish()
relu=nn.ReLU()

# %% [markdown]
# # Clasificación con torch
#
# Vamos a generar datos de dos circulos con ruido y vamos a utilizar una red neuronal creada en torch para separar los datos de los dos circulos.

# %%
# Creamos los datos
n=500
entry_params=2

X,Y=make_circles(n_samples=n,factor=0.5, noise=0.05)

Y=Y[:,np.newaxis]

plt.scatter(X[:,0], X[:,1])
plt.title("Puntos del dataset")
plt.show()

#Queremos separar los dos circulos así:
plt.scatter(X[Y[:,0] == 0,0], X[Y[:,0] == 0,1], c='b')
plt.scatter(X[Y[:,0] == 1,0], X[Y[:,0] == 1,1], c='r')
plt.title("Como queremos que separe")
plt.show()

# %%
# creamos nuestra red neuronal
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        
        self.layer1 = nn.Linear(2,4)
        self.layer2 = nn.Linear(4,8)
        self.layer3 = nn.Linear(8,16)
        self.layer4 = nn.Linear(16,8)
        self.layer5 = nn.Linear(8,4)
        self.layer6 = nn.Linear(4,1)

    def forward(self, x):
        x = relu(self.layer1(x))
        x = relu(self.layer2(x))
        x = relu(self.layer3(x))
        x = relu(self.layer4(x))
        x = relu(self.layer5(x))
        x = self.layer6(x)
        return x

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
model = Net().to(device)
print(model)

# create your optimizer
optimizer = optim.SGD(model.parameters(), lr=0.03)

criterion = nn.MSELoss()
# Out:
# Using cpu device
# Net(
#   (layer1): Linear(in_features=2, out_features=4, bias=True)
#   (layer2): Linear(in_features=4, out_features=8, bias=True)
#   (layer3): Linear(in_features=8, out_features=16, bias=True)
#   (layer4): Linear(in_features=16, out_features=8, bias=True)
#   (layer5): Linear(in_features=8, out_features=4, bias=True)
#   (layer6): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
# Transformamos los datos que tenemos en numpy a tensores de torch:
# Trasformar de numpy a Tensor
X_np = torch.from_numpy(X).float().to(device)
Y_np = torch.from_numpy(Y).float().to(device)

# %%
for i in range(20000):
  result = model(X_np)
  #soft = nn.Softmax(dim=1)(result)
  #print(soft.shape)

  loss = criterion(result, Y_np)
  if i % 100 == 0:
    print("ERROR: ", loss.item(), "EPOCH: ", i)


  model.zero_grad()

  loss.backward()
  """
  print(model.layer1.bias.grad)
  print(model.layer2.bias.grad)
  print(model.layer3.bias.grad)
  print(model.layer4.bias.grad)
  print(model.layer5.bias.grad)
  print(model.layer6.bias.grad)
  """
  optimizer.step()

  np_result = result.cpu().detach().numpy()
  if i != 0 and i % 500 == 0:
    plt.scatter(X[np_result[:,0] < 0.5,0], X[np_result[:,0] < 0.5,1], c='skyblue')
    plt.scatter(X[np_result[:,0] > 0.5,0], X[np_result[:,0] > 0.5,1], c='salmon')
    plt.show()
  if i != 0 and i % 19999 == 0:
    print(result)

  if loss.item() < 0.0015:
    break
# Out:
# ERROR:  0.5625523328781128 EPOCH:  0
# ERROR:  0.25039246678352356 EPOCH:  100
# ERROR:  0.24915581941604614 EPOCH:  200
# ERROR:  0.248015895485878 EPOCH:  300
# ERROR:  0.24677197635173798 EPOCH:  400
# ERROR:  0.24522623419761658 EPOCH:  500
# ERROR:  0.24309439957141876 EPOCH:  600
# ERROR:  0.23993442952632904 EPOCH:  700
# ERROR:  0.23479312658309937 EPOCH:  800
# ERROR:  0.2256474494934082 EPOCH:  900
# ERROR:  0.20624032616615295 EPOCH:  1000
# ERROR:  0.18196482956409454 EPOCH:  1100
# ERROR:  0.170847550034523 EPOCH:  1200
# ERROR:  0.16602124273777008 EPOCH:  1300
# ERROR:  0.0022353739477694035 EPOCH:  14200
# ERROR:  0.002217099769040942 EPOCH:  14300
# ERROR:  0.0021991811227053404 EPOCH:  14400
# ERROR:  0.0021809462923556566 EPOCH:  14500
# ERROR:  0.0021630607079714537 EPOCH:  14600
# ERROR:  0.0021451637148857117 EPOCH:  14700
# ERROR:  0.0021272802259773016 EPOCH:  14800
# ERROR:  0.002109516877681017 EPOCH:  14900
# ERROR:  0.002091852482408285 EPOCH:  15000
# ERROR:  0.0020740809850394726 EPOCH:  15100
# ERROR:  0.002056223340332508 EPOCH:  15200
# ERROR:  0.0020386783871799707 EPOCH:  15300
# ERROR:  0.002020998392254114 EPOCH:  15400
# ERROR:  0.0020033197943121195 EPOCH:  15500
# ERROR:  0.0019852183759212494 EPOCH:  15600
# ERROR:  0.001967474352568388 EPOCH:  15700
# ERROR:  0.0019497275352478027 EPOCH:  15800
# ERROR:  0.0019313533557578921 EPOCH:  15900
# ERROR:  0.0019132967572659254 EPOCH:  16000
# ERROR:  0.001894787303172052 EPOCH:  16100
# ERROR:  0.0018762031104415655 EPOCH:  16200
# ERROR:  0.0018578050658106804 EPOCH:  16300
# ERROR:  0.001839211443439126 EPOCH:  16400
# ERROR:  0.0018201913917437196 EPOCH:  16500
# ERROR:  0.0018015498062595725 EPOCH:  16600
# ERROR:  0.0017831557197496295 EPOCH:  16700
# ERROR:  0.0017648220527917147 EPOCH:  16800
# ERROR:  0.0017467470606788993 EPOCH:  16900
# ERROR:  0.0017285672947764397 EPOCH:  17000
# ERROR:  0.0017100638942793012 EPOCH:  17100
# ERROR:  0.0016912143910303712 EPOCH:  17200
# ERROR:  0.0016720353160053492 EPOCH:  17300
# ERROR:  0.0016536657931283116 EPOCH:  17400
# ERROR:  0.0016360885929316282 EPOCH:  17500
# ERROR:  0.0016191615723073483 EPOCH:  17600
# ERROR:  0.0016024820506572723 EPOCH:  17700
# ERROR:  0.001586827333085239 EPOCH:  17800
# ERROR:  0.0015712635358795524 EPOCH:  17900
# ERROR:  0.0015553849516436458 EPOCH:  18000
# ERROR:  0.001539683318696916 EPOCH:  18100
# ERROR:  0.0015244863461703062 EPOCH:  18200
# ERROR:  0.0015093483962118626 EPOCH:  18300

# %%
np_result = result.cpu().detach().numpy()
plt.scatter(X[np_result[:,0] < 0.5,0], X[np_result[:,0] < 0.5,1], c='skyblue')
plt.scatter(X[np_result[:,0] > 0.5,0], X[np_result[:,0] > 0.5,1], c='salmon')
plt.show()

# %%
# Creamos los datos de prueba
n=1000
entry_params=2

Xt,Yt=make_circles(n_samples=n,factor=0.4, noise=0.09)

Yt=Yt[:,np.newaxis]

plt.scatter(Xt[:,0], Xt[:,1])
plt.title("Puntos del dataset")
plt.show()

#Queremos separar los dos circulos así:
plt.scatter(Xt[Yt[:,0] == 0,0], Xt[Yt[:,0] == 0,1], c='b')
plt.scatter(Xt[Yt[:,0] == 1,0], Xt[Yt[:,0] == 1,1], c='r')
plt.title("Como queremos que separe")
plt.show()

# %%
X_test = torch.from_numpy(Xt).float().to(device)
result=model(X_test)
np_result = result.cpu().detach().numpy()

plt.scatter(Xt[np_result[:,0] < 0.5,0], Xt[np_result[:,0] < 0.5,1], c='b')
plt.scatter(Xt[np_result[:,0] > 0.5,0], Xt[np_result[:,0] > 0.5,1], c='r')
plt.title('Resultado obtenido con el modelo')
plt.show()
